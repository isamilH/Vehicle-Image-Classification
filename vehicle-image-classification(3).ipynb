jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (686).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (481).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (567).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (527).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (600).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (470).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (103).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (344).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (627).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (171).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (185).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (508).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (632).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (88).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (778).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (739).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (708).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (420).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (194).png
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (759).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (203).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (494).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (213).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (15).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (756).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (159).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (54).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (657).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (108).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (383).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (261).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (422).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (150).JPG
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (434).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (507).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (475).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (370).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (713).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (412).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (542).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (139).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (127).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (143).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (17).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (304).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (476).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (658).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (312).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (325).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (176).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (76).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (717).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (624).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (623).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (408).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (466).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (100).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (355).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (71).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (409).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (561).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (110).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (365).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (369).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (156).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (774).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (644).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (537).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (149).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (750).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (270).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (273).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (687).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (267).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (1).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (148).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (358).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (520).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (209).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (21).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (696).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (720).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (583).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (125).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (281).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (25).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (468).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (740).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (245).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (49).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (495).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (219).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (511).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (89).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (633).webp
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (212).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (697).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (610).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (625).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (631).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (612).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (166).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (265).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (46).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (734).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (349).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (336).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (497).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (423).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (589).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (536).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (75).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (552).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (374).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (529).JPG
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (138).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (646).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (279).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (656).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (282).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (706).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (277).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (785).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (565).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (37).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (386).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (783).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (768).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (721).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (13).png
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (695).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (709).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (317).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (570).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (50).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (91).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (215).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (795).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (117).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (244).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (733).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (417).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (191).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (348).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (190).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (63).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (659).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (258).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (777).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (684).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (431).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (455).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (2).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (794).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (675).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (24).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (115).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (266).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (463).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (444).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (120).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (569).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (59).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (399).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (439).png
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (193).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (492).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (447).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (449).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (287).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (504).JPG
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (579).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (65).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (480).PNG
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (727).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (452).png
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (145).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (604).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (256).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (753).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (284).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (796).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (598).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (515).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (351).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (445).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (6).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (30).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (693).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (590).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (299).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (290).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (141).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (137).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (790).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (337).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (755).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (250).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (112).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (784).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (464).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (606).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (319).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (459).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (363).JPG
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (335).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (323).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (619).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (226).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (645).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (97).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (629).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (547).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (128).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (478).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (597).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (411).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (233).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (429).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (563).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (398).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (603).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (462).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (718).webp
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (142).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (154).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (616).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (62).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (285).jpg
# /kaggle/input/vehicle-classification/Vehicles/Planes/Plane (424).jpg

# %%
import shutil
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
main_dir = "/kaggle/input/vehicle-classification/Vehicles"
categories = ["Auto Rickshaws", "Bikes", "Cars", "Motorcycles", "Planes", "Ships", "Trains"]

# %%
split_dirs = ["train", "val", "test"]
base_split_dir = "/kaggle/working/vehicles_split"

for split_dir in split_dirs:
    for category in categories:
        os.makedirs(os.path.join(base_split_dir, split_dir, category), exist_ok=True)

# %%
for category in categories:
    category_path = os.path.join(main_dir, category)
    images = os.listdir(category_path)
    train_images, temp_images = train_test_split(images, test_size=0.3, random_state=42)
    val_images, test_images = train_test_split(temp_images, test_size=0.5, random_state=42)

    def move_images(image_list, destination):
        for image in image_list:
            shutil.copy(os.path.join(category_path, image), os.path.join(base_split_dir, destination, category, image))

    move_images(train_images, "train")
    move_images(val_images, "val")
    move_images(test_images, "test")

# %%
train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=20, width_shift_range=0.2,
                                   height_shift_range=0.2, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(os.path.join(base_split_dir, "train"), target_size=(150, 150),
                                                    batch_size=32, class_mode='categorical')
val_generator = val_test_datagen.flow_from_directory(os.path.join(base_split_dir, "val"), target_size=(150, 150),
                                                     batch_size=32, class_mode='categorical')
test_generator = val_test_datagen.flow_from_directory(os.path.join(base_split_dir, "test"), target_size=(150, 150),
                                                      batch_size=32, class_mode='categorical')
# Out:
# Found 3911 images belonging to 7 classes.
# Found 837 images belonging to 7 classes.
# Found 839 images belonging to 7 classes.

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16

base_model = VGG16(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
# Fine-tune the deeper layers if needed
base_model.trainable = True
for layer in base_model.layers[:15]:  # Freeze the initial layers
    layer.trainable = False

# Create the model
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),  # Replaces Flatten for better feature aggregation
    Dense(512, activation='relu'),
    BatchNormalization(),      # Normalizes activations and speeds up convergence
    Dropout(0.5),              # Regularization to reduce overfitting
    Dense(7, activation='softmax')  # Final output layer for 7 vehicle classes
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
# Compile the model with a custom learning rate
optimizer = Adam(learning_rate=0.0001)  # Fine-tuning requires a smaller learning rate
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_generator, epochs=10, validation_data=val_generator)
# Out:
# Epoch 1/10
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 54s 390ms/step - accuracy: 0.9734 - loss: 0.0783 - val_accuracy: 0.9450 - val_loss: 0.2473
# Epoch 2/10
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 47s 363ms/step - accuracy: 0.9600 - loss: 0.1073 - val_accuracy: 0.9152 - val_loss: 0.3941
# Epoch 3/10
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 47s 360ms/step - accuracy: 0.9720 - loss: 0.0746 - val_accuracy: 0.9534 - val_loss: 0.2004
# Epoch 4/10
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 47s 369ms/step - accuracy: 0.9777 - loss: 0.0732 - val_accuracy: 0.9415 - val_loss: 0.2654
# Epoch 5/10
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 47s 370ms/step - accuracy: 0.9710 - loss: 0.0805 - val_accuracy: 0.9450 - val_loss: 0.2137
# Epoch 6/10
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 48s 370ms/step - accuracy: 0.9853 - loss: 0.0448 - val_accuracy: 0.9176 - val_loss: 0.3748
# Epoch 7/10
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 48s 375ms/step - accuracy: 0.9781 - loss: 0.0663 - val_accuracy: 0.9247 - val_loss: 0.3414
# Epoch 8/10
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 47s 368ms/step - accuracy: 0.9818 - loss: 0.0618 - val_accuracy: 0.9594 - val_loss: 0.2234
# Epoch 9/10
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 47s 362ms/step - accuracy: 0.9829 - loss: 0.0542 - val_accuracy: 0.9534 - val_loss: 0.1690
# Epoch 10/10
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 48s 369ms/step - accuracy: 0.9812 - loss: 0.0539 - val_accuracy: 0.9642 - val_loss: 0.1542

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 291ms/step - accuracy: 0.9638 - loss: 0.1220
# Test accuracy: 96.78%

# %%
import matplotlib.pyplot as plt
import random
from tensorflow.keras.preprocessing.image import img_to_array, load_img


test_images, test_labels = next(test_generator)
indices = random.sample(range(len(test_images)), 9)

predictions = model.predict(test_images[indices])
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(test_labels[indices], axis=1)

plt.figure(figsize=(10, 10))
for i, idx in enumerate(indices):
    plt.subplot(3, 3, i + 1)
    plt.imshow(test_images[idx])
    plt.axis('off')

    true_label = categories[true_labels[i]]
    predicted_label = categories[predicted_labels[i]]
    color = 'green' if true_label == predicted_label else 'red'

    plt.title(f"True: {true_label}\nPred: {predicted_label}", color=color)

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
# Save the entire model
model.save('vehicle_classification_model.h5')
